# %% [markdown]
# <a href="https://colab.research.google.com/github/musa996/python_project/blob/main/print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
print("my name is alex")
print("i love playing soccar")
print(9)
print(3.1415)
print(3.1415,9)
print(3.1415,"\n",9)
print("hello\n", 9)
print(1+2)
"""
multilined comment
"""
# single lined comment
# Out:
# hello world
# my name is alex
# i love playing soccar
# 9
# 3.1415
# 3.1415 9
# 3.1415
#  9
# hello
#  9

# %%
print("welcome to the world of programming")
print(4)
print("hello", 5)
print("welcome")
print("hello python\n",27)
print(9,5,"\end")
print("alex","\nmax")
print("hi" , end = " ")
print("bye")
# Out:
# welcome to the world of programming
# 4
# hello 5
# welcome
# hello python
#  27
# 9 5 \end
# alex
# max
# hi bye
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_31444/978608150.py:6: SyntaxWarning: invalid escape sequence '\e'
#   print(9,5,"\end")
